# %%
# project description:
#

# %%
# install dependencies
# !pip install plotly pandas requests geopy
# Out:
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.12/site-packages (5.24.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: geopy in /opt/anaconda3/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from plotly) (24.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/anaconda3/lib/python3.12/site-packages (from geopy) (2.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# download the Epoch AI data
import pandas as pd
import requests
from io import StringIO

dc_url = "https://epoch.ai/data/data_centers/data_centers.csv"
tl_url = "https://epoch.ai/data/data_centers/data_center_timelines.csv"

dc_raw = requests.get(dc_url).text
tl_raw = requests.get(tl_url).text

dc = pd.read_csv(StringIO(dc_raw))
tl = pd.read_csv(StringIO(tl_raw))

print(dc.shape, dc.columns.tolist())
print(tl.shape, tl.columns.tolist())
# Out:
# (43, 15) ['Name', 'Current H100 equivalents', 'Current power (MW)', 'Current total capital cost (2025 USD billions)', 'Owner', 'Users', 'Notes', 'Selected Sources', 'Calculations sheet', 'Project', 'Investors', 'Construction companies', 'Energy companies', 'Country', 'Address']
# (247, 14) ['Date', 'Construction status', 'Buildings operational', 'IT power (MW)', 'Power (MW)', 'H100 equivalents', 'Total capital cost (2025 USD billions)', 'Performance (8-bit OP/s)', 'Compute cost (2025 USD billions)', 'Construction cost (2025 USD billions)', 'Water use (MGD)', 'Data center', 'Current H100 equivalents (from Data center)', 'Thumbnail']

# %%
# explore data
print(dc[['Name', 'Owner', 'Country', 'Address', 'Current power (MW)']].to_string())
# Out:
#                               Name                  Owner               Country                                                                                                       Address  Current power (MW)
# 0                       Colossus 2    SpaceXAI #confident         United States                                                                             5420 Tulane Rd, Memphis, TN 38109             1494.00
# 1      Microsoft Fairwater Atlanta   Microsoft #confident         United States                                                                         1435 Hwy 54 W, Fayetteville, GA 30214              859.00
# 2    Anthropic-Amazon New Carlisle      Amazon #confident         United States                                                                   55001 Larrison Blvd, New Carlisle, IN 46552             1092.00
# 3    Microsoft Fairwater Wisconsin   Microsoft #confident         United States                                                                        4800 90th St, Mount Pleasant, WI 53403              555.00
# 4                  Meta Prometheus        Meta #confident         United States                                                                         1 Community Cir, New Albany, OH 43054              531.00
# 5                     QTS Richmond                    NaN         United States                                                                      6000 Technology Blvd, Sandston, VA 23150              854.00
# 6                       Colossus 1    SpaceXAI #confident         United States                                                                          3231 Riverport Rd, Memphis, TN 38109              425.38
# 7          OpenAI Stargate Abilene      Oracle #confident         United States                                                                             5502 Spinks Rd, Abilene, TX 79601              295.00
# 8                  Google Columbus      Google #confident         United States                                                                            5076 S High St, Columbus, OH 43207              364.00
# 9         Amazon Madison Mega Site      Amazon #confident         United States  Amazon Data Services Inc, Madison Mega Site Nissan Parkway and Highway 22 Canton, Mississippi Madison County              341.00
# 10               Google New Albany      Google #confident         United States                                                                        1101 Beech Rd SW, New Albany, OH 43054              407.00
# 11              Microsoft Goodyear   Microsoft #confident         United States                                                                       14250 W Broadway Rd, Goodyear, AZ 85338              263.00
# 12                     Meta Temple        Meta #confident         United States                                                                           2310 Eberhardt Rd, Temple, TX 76504              198.00
# 13                    Google Omaha      Google #confident         United States                                                                               11110 State St, Omaha, NE 68142              284.00
# 14                Alibaba Zhangbei     Alibaba #confident                 China              Alibaba Zhangbei Yun Calculation Data Center, Zhangbei County, Zhangjiakou, Hebei, China, 076471              203.00
# 15             CoreWeave Denton TX              CoreWeave         United States                                                                        8171 Jim Christal Rd, Denton, TX 76207              183.40
# 16        Microsoft Project Osmium   Microsoft #confident         United States                                                                           5855 SW Kerry St, Cumming, IA 50061              228.00
# 17    Google Council Bluffs (East)      Google #confident         United States                                                                     10410 Bunge Ave, Council Bluffs, IA 51503              190.00
# 18            Google Storey County      Google #confident         United States                                                                                                           NaN              214.00
# 19                    Oracle Batam         Oracle #likely             Indonesia                                                                                                           NaN               94.00
# 20         Fluidstack Lake Mariner  Fluidstack #confident         United States                                                                                7725 Lake Rd, Barker, NY 14012               68.00
# 21      STACK Infrastructure NVA02                    NaN         United States                                                                         9590 Hornbaker Rd, Manassas, VA 20109              118.00
# 22                  Stream Phoenix                    NaN         United States                                                                                       2950 S. Litchfield Road               77.00
# 23                     Vantage TX1                    NaN         United States                                                                                       Goodyear, Arizona 85338               44.80
# 24  Start Campus Sines Data Campus      Nscale #confident              Portugal                                              Start Campus - Sustainable Data Center Services, Sines, Portugal               40.00
# 25            Google Pryor (North)      Google #confident         United States                                                                                 4581 Webb St, Pryor, OK 74361               65.00
# 26                   Meta Hyperion        Meta #confident         United States                                                                                         Holly Ridge, LA 71269                0.00
# 27                       Goodnight    Google #speculative         United States                                                                               10001 Lima Rd, Claude, TX 79019                0.00
# 28                Amazon Ridgeland      Amazon #confident         United States                                                                  1626 County Line Road Ridgeland, Mississippi                0.00
# 29             OpenAI Stargate UAE            G42 #likely  United Arab Emirates                             Nexus L&T Project Office, Al Bihouth, Al Dhafrah, Abu Dhabi, United Arab Emirates                0.00
# 30                Coreweave Helios   Coreweave #confident         United States                                                                          984 County Road 112, Afton, TX 79920                0.00
# 31             Google Cedar Rapids      Google #confident         United States                                                                    5800 EDGEWOOD RD SW CEDAR RAPIDS, IA 52404                0.00
# 32                QTS Cedar Rapids                    NaN         United States                                                                           6200 76th Ave SW, Fairfax, IA 52228                0.00
# 33     OpenAI Stargate Shackelford      Oracle #confident         United States                                                  175 Private Road 1604, Abilene, TX 79601, Shackelford County                0.00
# 34               Google Fort Wayne      Google #confident         United States                                                                  6015 Adams Center Road, Fort Wayne, IN 46806                0.00
# 35        Crusoe Abilene Expansion   Microsoft #confident         United States                                                                             5502 Spinks Rd, Abilene, TX 79601                0.00
# 36       OpenAI Stargate Lordstown    Softbank #confident         United States                                                                       2300 Hallock Young Rd, Warren, OH 44481                0.00
# 37      OpenAI Stargate New Mexico      Oracle #confident         United States                                                                                                           NaN                0.00
# 38       OpenAI Stargate Wisconsin      Oracle #confident         United States                                                                                                           NaN                0.00
# 39        OpenAI Stargate Michigan      Oracle #confident         United States                                                                                                           NaN                0.00
# 40           OpenAI Stargate Milam    Softbank #confident         United States                                                                                                           NaN                0.00
# 41                       Meta Kuna        Meta #confident         United States                                                                              601 Kuna Mora Rd,  Kuna ID 83634                0.00
# 42         Google Kansas City East      Google #confident         United States                                                                                                           NaN                0.00

# %%
print(tl[['Date', 'Data center', 'Construction status', 'Power (MW)']].head(30).to_string())
# Out:
#           Date                     Data center                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Construction status  Power (MW)
# 0   2018-12-18        Microsoft Project Osmium                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Land clearing begins on the north part of the site         0.0
# 1   2019-10-19      STACK Infrastructure NVA02                                                                                                                                                                                                                                                                                                                                                                          Land clearing begins by Peterson Companies for Stack Infrastructure, which is noted in the [news](https://www.bisnow.com/washington-dc/news/data-center/peterson-cos-partnering-to-build-4m-sf-data-center-campus-in-manassas-102646) and visible on satellite imagery.         0.0
# 2   2021-01-01        Microsoft Project Osmium                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Building 1 and 1st building on the site are operational. Foundation work begins on Building 2        57.0
# 3   2021-06-21              Microsoft Goodyear                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Land clearing begins for Building 1.         0.0
# 4   2021-10-01                 Google Columbus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Land clearing begins on the eastern half of the site, for Buildings 1-2         0.0
# 5   2021-11-25                    Google Omaha                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins.         0.0
# 6   2022-01-01  Start Campus Sines Data Campus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Land clearing begins for Building 1 (SIN01)         0.0
# 7   2022-04-01                     Meta Temple                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins.         0.0
# 8   2022-04-01                    QTS Richmond                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins at site 2 (northeast). Buildings 1 and 2 in site 1 (northwest) are not running AI workloads at this point as is evident from the lack of cooling infrastructure.         0.0
# 9   2022-04-14                 Meta Prometheus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins for Building 1-2         0.0
# 10  2022-07-01                    Oracle Batam                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins.         0.0
# 11  2022-09-06    Google Council Bluffs (East)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Land clearing begins for east buildings         0.0
# 12  2022-10-03                       Meta Kuna                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins.         0.0
# 13  2022-10-30                  Stream Phoenix                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Construction beginning, as can be seen on satellite. Major renovations on western side of the non AI building (PX1), including adding generators and cooling towers.          0.0
# 14  2023-02-05                     Meta Temple                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      A traditional H-shaped Meta data center is partially built.         0.0
# 15  2023-04-01                     Meta Temple                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The traditional Meta data center has been demolished mid-construction, in favor of Meta's new AI-optimized design.         0.0
# 16  2023-04-09     Microsoft Fairwater Atlanta                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins for southern part (Building 1-2)         0.0
# 17  2023-04-24              Microsoft Goodyear                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Building 1 operational. Based on interpolating satellite images from Sentinel-2 and Google Earth.        53.0
# 18  2023-06-30        Microsoft Project Osmium                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Building 2 is operational. Estimated based on Microsoft H100 count 2023       114.0
# 19  2023-07-01                 Google Columbus                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Building 2 foundation work begins. Building 1 generators seem complete, cooling towers still under construction.         0.0
# 20  2023-07-14   Microsoft Fairwater Wisconsin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Land clearing begins for Building 1.         0.0
# 21  2023-08-30            Google Storey County  Building 1, which was first operational in 2021, has increased power capacity by about 75%. This is based on the expansion of the dry cooling array from 4 to 7 columns (seen on [Google Earth](https://earth.google.com/web/@39.4948785,-119.43174359,1568.8659293a,562.69639351d,35y,-0h,0t,0r/)). Its backup generators also grew from 18 to 33, an 83% increase. Around this time (2023 Q3) the quarterly PUE of the campus is 1.24, down from the initial 1.29 in 2022 Q3. Since no other buildings have been added, these changes indicate an increase in power density, which may entail a new generation of hardware getting installed.       107.0
# 22  2023-10-01                    QTS Richmond                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Land cleared for site 1 expansion, some materials down at substation site. Building 1 retrofitted and likely operational.        66.0
# 23  2023-10-02        Amazon Madison Mega Site                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Land clearing begins         0.0
# 24  2023-12-15                     Vantage TX1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Land clearing begins for both Building 1 & Building 2         0.0
# 25  2024-01-01         Google Kansas City East                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Land clearing has begun for the site         0.0
# 26  2024-02-09   Anthropic-Amazon New Carlisle                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Land clearing begins in the northern section         0.0
# 27  2024-02-24                Amazon Ridgeland                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Land clearing begins         0.0
# 28  2024-03-01         Google Kansas City East                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Foundation work begins on Building 1         0.0
# 29  2024-04-01                    QTS Richmond                                                                                                                                                                                                                                                                                                                                                                                                                              Building 2 (second square building) retrofitted with cooling infrastructure. Building 5 roof complete. Buildings 3 and 4 appear operational. Land cleared for site 3 (south). More activity around substation area.       167.0

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import time

# filter to US-only data centers with addresses
us_dc = dc[dc['Country'] == 'United States'].copy()
us_dc = us_dc[us_dc['Address'].notna()].copy()

# clean up 'Owner' column (strip #confident etc)
us_dc['Owner_clean'] = us_dc['Owner'].str.replace(r'\s*#\w+', '', regex=True).str.strip()
us_dc['Owner_clean'] = us_dc['Owner_clean'].fillna('Unknown')

# geocode
geolocator = Nominatim(user_agent="datacenter_map")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def get_coords(address):
    try:
        loc = geocode(address, timeout=10)
        if loc:
            return loc.latitude, loc.longitude
    except:
        pass
    return None, None

us_dc[['lat', 'lon']] = us_dc['Address'].apply(
    lambda a: pd.Series(get_coords(a))
)

print(us_dc[['Name', 'Owner_clean', 'lat', 'lon']].to_string())
# Out:
#                              Name Owner_clean        lat         lon
# 0                      Colossus 2    SpaceXAI  34.997983  -90.034867
# 1     Microsoft Fairwater Atlanta   Microsoft  33.445223  -84.524826
# 2   Anthropic-Amazon New Carlisle      Amazon        NaN         NaN
# 3   Microsoft Fairwater Wisconsin   Microsoft  42.674870  -87.894888
# 4                 Meta Prometheus        Meta        NaN         NaN
# 5                    QTS Richmond     Unknown  37.488827  -77.247490
# 6                      Colossus 1    SpaceXAI  35.073554  -90.087308
# 7         OpenAI Stargate Abilene      Oracle  32.494232  -99.800907
# 8                 Google Columbus      Google  39.861452  -83.004000
# 9        Amazon Madison Mega Site      Amazon        NaN         NaN
# 10              Google New Albany      Google  40.070051  -82.754042
# 11             Microsoft Goodyear   Microsoft  33.408991 -112.364800
# 12                    Meta Temple        Meta  31.125960  -97.359818
# 13                   Google Omaha      Google  41.335681  -96.052363
# 15            CoreWeave Denton TX   CoreWeave  33.219273  -97.174783
# 16       Microsoft Project Osmium   Microsoft        NaN         NaN
# 17   Google Council Bluffs (East)      Google  41.166650  -95.797741
# 20        Fluidstack Lake Mariner  Fluidstack  43.358655  -78.604128
# 21     STACK Infrastructure NVA02     Unknown  38.745806  -77.537725
# 22                 Stream Phoenix     Unknown  33.419491 -112.359988
# 23                    Vantage TX1     Unknown  33.467228 -112.385349
# 25           Google Pryor (North)      Google  36.241172  -95.330047
# 26                  Meta Hyperion        Meta  32.467642  -91.626788
# 27                      Goodnight      Google        NaN         NaN
# 28               Amazon Ridgeland      Amazon  32.400033  -90.197171
# 30               Coreweave Helios   Coreweave        NaN         NaN
# 31            Google Cedar Rapids      Google  41.922176  -91.715667
# 32               QTS Cedar Rapids     Unknown  41.905620  -91.751077
# 33    OpenAI Stargate Shackelford      Oracle        NaN         NaN
# 34              Google Fort Wayne      Google  41.030929  -85.053626
# 35       Crusoe Abilene Expansion   Microsoft  32.494232  -99.800907
# 36      OpenAI Stargate Lordstown    Softbank        NaN         NaN
# 41                      Meta Kuna        Meta  43.459207 -116.421111

# %%
# prep the timeline data ---

# parse dates, join timeline to DC locations
tl['Date'] = pd.to_datetime(tl['Date'])
tl['Year'] = tl['Date'].dt.year

# only keep operational entries (Power > 0)
tl_op = tl[tl['Power (MW)'] > 0].copy()

# for each data center and year, take the max power achieved that year
tl_yearly = (
    tl_op.groupby(['Data center', 'Year'])['Power (MW)']
    .max()
    .reset_index()
)

print(tl_yearly.sort_values(['Data center', 'Year']).to_string())
# Out:
#                        Data center  Year  Power (MW)
# 0                 Alibaba Zhangbei  2025      102.00
# 1                 Alibaba Zhangbei  2026      203.00
# 2         Amazon Madison Mega Site  2025      341.00
# 3         Amazon Madison Mega Site  2026      819.00
# 4                 Amazon Ridgeland  2026      273.00
# 5                 Amazon Ridgeland  2027     1008.00
# 6    Anthropic-Amazon New Carlisle  2025      751.00
# 7    Anthropic-Amazon New Carlisle  2026     1229.00
# 8                       Colossus 1  2024      181.00
# 9                       Colossus 1  2025      442.00
# 10                      Colossus 1  2026      425.38
# 11                      Colossus 2  2025      299.00
# 12                      Colossus 2  2026     1494.00
# 13             CoreWeave Denton TX  2025       93.80
# 14             CoreWeave Denton TX  2026      366.80
# 15                Coreweave Helios  2026      200.00
# 16                Coreweave Helios  2028      600.00
# 17                Coreweave Helios  2029      800.00
# 18        Crusoe Abilene Expansion  2027      941.00
# 19         Fluidstack Lake Mariner  2025       19.00
# 20         Fluidstack Lake Mariner  2026      313.00
# 21         Fluidstack Lake Mariner  2027      509.00
# 22                       Goodnight  2026      265.00
# 23                       Goodnight  2027     1087.60
# 24             Google Cedar Rapids  2026      105.00
# 25             Google Cedar Rapids  2027      314.00
# 26             Google Cedar Rapids  2029      523.00
# 27             Google Cedar Rapids  2030      627.00
# 28                 Google Columbus  2024       78.00
# 29                 Google Columbus  2025      260.00
# 30                 Google Columbus  2026      364.00
# 31                 Google Columbus  2027      464.00
# 32    Google Council Bluffs (East)  2024       95.00
# 33    Google Council Bluffs (East)  2025      190.00
# 34    Google Council Bluffs (East)  2026      284.00
# 35               Google Fort Wayne  2026      207.00
# 36               Google Fort Wayne  2028     1035.00
# 37         Google Kansas City East  2026      126.00
# 38               Google New Albany  2024      177.00
# 39               Google New Albany  2025      407.00
# 40               Google New Albany  2026      543.00
# 41                    Google Omaha  2024      189.00
# 42                    Google Omaha  2025      189.00
# 43                    Google Omaha  2026      284.00
# 44                    Google Omaha  2027      474.00
# 45            Google Pryor (North)  2024       65.00
# 46            Google Pryor (North)  2025       65.00
# 47            Google Pryor (North)  2026      454.00
# 48            Google Storey County  2023      107.00
# 49            Google Storey County  2025      214.00
# 50            Google Storey County  2026      214.00
# 51            Google Storey County  2027      389.00
# 52                   Meta Hyperion  2028     2262.00
# 53                       Meta Kuna  2026      198.00
# 54                 Meta Prometheus  2025       99.00
# 55                 Meta Prometheus  2026     1110.00
# 56                     Meta Temple  2025      198.00
# 57                     Meta Temple  2026      238.00
# 58     Microsoft Fairwater Atlanta  2025      433.00
# 59     Microsoft Fairwater Atlanta  2026      859.00
# 60   Microsoft Fairwater Wisconsin  2026      555.00
# 61   Microsoft Fairwater Wisconsin  2027     3328.00
# 62              Microsoft Goodyear  2023       53.00
# 63              Microsoft Goodyear  2025      263.00
# 64        Microsoft Project Osmium  2021       57.00
# 65        Microsoft Project Osmium  2023      114.00
# 66        Microsoft Project Osmium  2025      228.00
# 67         OpenAI Stargate Abilene  2025      295.00
# 68         OpenAI Stargate Abilene  2026     1180.00
# 69        OpenAI Stargate Michigan  2028     1383.00
# 70           OpenAI Stargate Milam  2028     1200.00
# 71      OpenAI Stargate New Mexico  2028     2210.00
# 72     OpenAI Stargate Shackelford  2027      196.00
# 73     OpenAI Stargate Shackelford  2028     1960.00
# 74             OpenAI Stargate UAE  2026      280.00
# 75             OpenAI Stargate UAE  2028     1400.00
# 76       OpenAI Stargate Wisconsin  2028     1300.00
# 77                    Oracle Batam  2025       43.00
# 78                    Oracle Batam  2026       94.00
# 79                QTS Cedar Rapids  2026      627.00
# 80                QTS Cedar Rapids  2027     1587.00
# 81                    QTS Richmond  2023       66.00
# 82                    QTS Richmond  2024      434.00
# 83                    QTS Richmond  2025      854.00
# 84                    QTS Richmond  2026      921.00
# 85      STACK Infrastructure NVA02  2024      118.00
# 86      STACK Infrastructure NVA02  2026      118.00
# 87      STACK Infrastructure NVA02  2028      487.00
# 88  Start Campus Sines Data Campus  2026       40.00
# 89  Start Campus Sines Data Campus  2027      280.00
# 90                  Stream Phoenix  2026       77.00
# 91                  Stream Phoenix  2030      267.00
# 92                     Vantage TX1  2026       44.80
# 93                     Vantage TX1  2027      179.20

# %%
# since some cell coordinates are missing, find ai data centers that are missing by filtering

missing = us_dc[us_dc['lat'].isna()][['Name', 'Address']]
print(missing.to_string())
# Out:
#                              Name                                                                                                       Address
# 2   Anthropic-Amazon New Carlisle                                                                   55001 Larrison Blvd, New Carlisle, IN 46552
# 4                 Meta Prometheus                                                                         1 Community Cir, New Albany, OH 43054
# 9        Amazon Madison Mega Site  Amazon Data Services Inc, Madison Mega Site Nissan Parkway and Highway 22 Canton, Mississippi Madison County
# 16       Microsoft Project Osmium                                                                           5855 SW Kerry St, Cumming, IA 50061
# 27                      Goodnight                                                                               10001 Lima Rd, Claude, TX 79019
# 30               Coreweave Helios                                                                          984 County Road 112, Afton, TX 79920
# 33    OpenAI Stargate Shackelford                                                  175 Private Road 1604, Abilene, TX 79601, Shackelford County
# 36      OpenAI Stargate Lordstown                                                                       2300 Hallock Young Rd, Warren, OH 44481

# %%
import plotly.express as px

# join timeline to location/owner data
merged = tl_yearly.merge(
    us_dc[['Name', 'Owner_clean', 'lat', 'lon']],
    left_on='Data center',
    right_on='Name',
    how='inner'
)

# cumulative max power per site per year
all_years = sorted(range(merged['Year'].min(), merged['Year'].max() + 1))
rows = []
for name in merged['Name'].unique():
    site = merged[merged['Name'] == name].set_index('Year')
    owner = site['Owner_clean'].iloc[0]
    lat = site['lat'].iloc[0]
    lon = site['lon'].iloc[0]
    for year in all_years:
        past = site[site.index <= year]
        if not past.empty:
            power = past['Power (MW)'].max()
            rows.append({
                'Name': name,
                'Owner_clean': owner,
                'lat': lat,
                'lon': lon,
                'Power (MW)': power,
                'Year': str(year),
            })

anim_df = pd.DataFrame(rows)

# add a dummy invisible row for every owner in every year
# so Plotly's color mapping stays consistent across frames
all_owners = anim_df['Owner_clean'].unique()
dummy_rows = []
for year in [str(y) for y in all_years]:
    for owner in all_owners:
        dummy_rows.append({
            'Name': f'__dummy_{owner}',
            'Owner_clean': owner,
            'lat': 0, 'lon': 0,
            'Power (MW)': 0,
            'Year': year,
        })
anim_df = pd.concat([anim_df, pd.DataFrame(dummy_rows)], ignore_index=True)
anim_df = anim_df.sort_values(['Year', 'Name'])

owner_colors = {
    'Microsoft': '#00a2ed',
    'Meta': '#1877f2',
    'Google': '#34a853',
    'Amazon': '#ff9900',
    'Oracle': '#f80000',
    'SpaceXAI': '#cc0000',
    'CoreWeave': '#7b2d8b',
    'Coreweave': '#7b2d8b',
    'Fluidstack': '#00b4d8',
    'Unknown': '#aaaaaa',
    'Softbank': '#cc6600',
}

fig = px.scatter_geo(
    anim_df,
    lat='lat',
    lon='lon',
    size='Power (MW)',
    color='Owner_clean',
    hover_name='Name',
    hover_data={'Power (MW)': True, 'Owner_clean': True, 'lat': False, 'lon': False},
    animation_frame='Year',
    scope='usa',
    size_max=60,
    color_discrete_map=owner_colors,
    title='US AI Data Centers and Power Capacity (megawatts) Growth Over Time',
)

# hide dummy points from hover
fig.for_each_trace(lambda t: t.update(
    hovertemplate=None,
    hoverinfo='skip',
) if '__dummy' in str(t.name) else None)

fig.update_layout(
    geo=dict(
        bgcolor='#0f0f0f',
        landcolor='#1a1a2e',
        lakecolor='#16213e',
        subunitcolor='#444',
        showland=True,
        showlakes=True,
        showsubunits=True,
    ),
    paper_bgcolor='#0f0f0f',
    plot_bgcolor='#0f0f0f',
    font=dict(color='white'),
    legend=dict(bgcolor='#1a1a2e', bordercolor='#444', borderwidth=1),
    title_font=dict(size=18),
)

fig.write_html('ai_datacenters_animated.html')
print("Saved to ai_datacenters_animated.html")
fig.show()
# Out:
# Saved to ai_datacenters_animated.html
